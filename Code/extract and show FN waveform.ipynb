# %% [markdown]
# # FN waveforms from test dataset
# ---
# you can use this code after testing your prediction model.
# - x_test : waveform dataset for test
# - y_test : true value (labels)
# - y_pred : prediction results
#
# [prediction code]: https://github.com/kyulee-jeon/PROPHECY-STEMI/Code/ Model and Visualization.ipynb

# %% [markdown]
# ### (1) find the index

# %%
df_y_test = pd.DataFrame(y_test) # STEMI label 
df_y_pred = pd.DataFrame(y_pred) # STEMI 예측결과

# %%
wrong_index = []

for i in range(len(df_y_test)):
    if df_y_test[1][i] ==1 and df_y_test[0][i] != df_y_pred[0][i]:
        wrong_index.append(i)

# %%
len(wrong_index)
# Out:
# 72

# %% [markdown]
# ### (2) find the waveform

# %%
x_wrong = []
for i in wrong_index:
    wrong_ecg = x_test[i]
    x_wrong.append(wrong_ecg)

# %%
len(x_wrong)
# Out:
# 72

# %% [markdown]
# ### (3) show only one waveform for test

# %%
def show_waveform(df_x):
    lead_I = df_x[0].to_numpy()
    lead_II = df_x[1].to_numpy()
    lead_V1 = df_x[2].to_numpy()
    lead_V2 = df_x[3].to_numpy()
    lead_V3 = df_x[4].to_numpy()
    lead_V4 = df_x[5].to_numpy()
    lead_V5 = df_x[6].to_numpy()
    lead_V6 = df_x[7].to_numpy()   
    
    size = (40,15)
    font_size = 25
    fig, ax = plt.subplots(8, 1)
    
    
    ax[0].plot(lead_I)
    ax[0].set_title('I',fontweight="bold", size=font_size)
    plt.rcParams["figure.figsize"] = size

    ax[1].plot(lead_II)
    ax[1].set_title('II',fontweight="bold", size=font_size)
    plt.rcParams["figure.figsize"] = size

    ax[2].plot(lead_V1)
    ax[2].set_title('V1',fontweight="bold", size=font_size)
    plt.rcParams["figure.figsize"] = size

    ax[3].plot(lead_V2)
    ax[3].set_title('V2',fontweight="bold", size=font_size)
    plt.rcParams["figure.figsize"] = size

    ax[4].plot(lead_V3)
    ax[4].set_title('V3',fontweight="bold", size=font_size)
    plt.rcParams["figure.figsize"] = size

    ax[5].plot(lead_V4)
    ax[5].set_title('V4',fontweight="bold", size=font_size)
    plt.rcParams["figure.figsize"] = size

    ax[6].plot(lead_V5)
    ax[6].set_title('V5',fontweight="bold", size=font_size)
    plt.rcParams["figure.figsize"] = size

    ax[7].plot(lead_V6)
    ax[7].set_title('V6',fontweight="bold", size=font_size)
    plt.rcParams["figure.figsize"] = size
    
    fig.tight_layout()
    plt.show()

#    plt.savefig('test.png')

# %%
df_eg = pd.DataFrame(x_test[0])
show_waveform(df_eg)

# %% [markdown]
# ### (4) save the FN waveform

# %%
def save_waveform(df_x):
    lead_I = df_x[0].to_numpy()
    lead_II = df_x[1].to_numpy()
    lead_V1 = df_x[2].to_numpy()
    lead_V2 = df_x[3].to_numpy()
    lead_V3 = df_x[4].to_numpy()
    lead_V4 = df_x[5].to_numpy()
    lead_V5 = df_x[6].to_numpy()
    lead_V6 = df_x[7].to_numpy()   
    
    size = (40,15)
    font_size = 25
    fig, ax = plt.subplots(8, 1)
    
    
    ax[0].plot(lead_I)
    ax[0].set_title('I',fontweight="bold", size=font_size)
    plt.rcParams["figure.figsize"] = size

    ax[1].plot(lead_II)
    ax[1].set_title('II',fontweight="bold", size=font_size)
    plt.rcParams["figure.figsize"] = size

    ax[2].plot(lead_V1)
    ax[2].set_title('V1',fontweight="bold", size=font_size)
    plt.rcParams["figure.figsize"] = size

    ax[3].plot(lead_V2)
    ax[3].set_title('V2',fontweight="bold", size=font_size)
    plt.rcParams["figure.figsize"] = size

    ax[4].plot(lead_V3)
    ax[4].set_title('V3',fontweight="bold", size=font_size)
    plt.rcParams["figure.figsize"] = size

    ax[5].plot(lead_V4)
    ax[5].set_title('V4',fontweight="bold", size=font_size)
    plt.rcParams["figure.figsize"] = size

    ax[6].plot(lead_V5)
    ax[6].set_title('V5',fontweight="bold", size=font_size)
    plt.rcParams["figure.figsize"] = size

    ax[7].plot(lead_V6)
    ax[7].set_title('V6',fontweight="bold", size=font_size)
    plt.rcParams["figure.figsize"] = size
    
    fig.tight_layout()

# %%
image_dir = my_path+'/false_negative_ecg/'

# %%
for i in range(len(x_wrong)): 
    df_ECG = pd.DataFrame(x_wrong[i])
    save_waveform(df_ECG)
    plt.savefig(image_dir+'test_'+str(i)+'.png')
# Out:
# /tmp/ipykernel_3813/2581255624.py:49: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   fig.tight_layout()
# /tmp/ipykernel_3813/2581255624.py:14: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(8, 1)
